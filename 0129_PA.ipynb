# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Generate a BA graph with 2000 nodes, d=3, p=1
BA = nx.random_graphs.barabasi_albert_graph(2000, 3)

# %%
plt.figure(figsize=(12, 8))
nx.draw(BA, with_labels = False, node_size = 5)

# %%
degree_freq = nx.degree_histogram(BA)
degrees = range(1, len(degree_freq)+1)
plt.figure(figsize=(12, 8))
plt.loglog(degrees[3:], degree_freq[3:], 'o')
plt.xlabel('Degree')
plt.ylabel('Frequency')
plt.title('Plot of Frequency against Degree for BA Model')
# Out:
# Text(0.5, 1.0, 'Plot of Frequency against Degree for BA Model')
